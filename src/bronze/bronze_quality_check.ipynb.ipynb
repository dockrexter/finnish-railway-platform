# %%
from pyspark.sql.functions import count, col, current_timestamp

# %%
# Check tables
tables = ['bronze_live_trains', 'bronze_stations_cdc']  # Update with exact names from your notebooks
for table in tables:
    df = spark.table(f"rail_lakehouse.bronze_rail.{table}")
    row_count = df.count()
    print(f"{table}: {row_count} rows")
    
    # Quick schema peek
    df.printSchema()
